# %% [markdown]
# # EDA ON VICTIMS_OF_RAPE DATASET

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Victims_of_rape.csv')
df
# Out:
#                       Area_Name  Year                Subgroup  \
# 0     Andaman & Nicobar Islands  2001      Total Rape Victims
# 1     Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2     Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3     Andaman & Nicobar Islands  2002      Total Rape Victims
# 4     Andaman & Nicobar Islands  2002  Victims of Incest Rape
# ...                         ...   ...                     ...
# 1045                West Bengal  2009  Victims of Incest Rape
# 1046                West Bengal  2009   Victims of Other Rape
# 1047                West Bengal  2010      Total Rape Victims
# 1048                West Bengal  2010  Victims of Incest Rape
# 1049                West Bengal  2010   Victims of Other Rape
#
#       Rape_Cases_Reported  Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 0                       3                     0                          0
# ...

# %%
df.shape
# Out:
# (1050, 11)

# %%
df.columns
# Out:
# Index(['Area_Name', 'Year', 'Subgroup', 'Rape_Cases_Reported',
#        'Victims_Above_50_Yrs', 'Victims_Between_10-14_Yrs',
#        'Victims_Between_14-18_Yrs', 'Victims_Between_18-30_Yrs',
#        'Victims_Between_30-50_Yrs', 'Victims_of_Rape_Total',
#        'Victims_Upto_10_Yrs'],
#       dtype='object')

# %% [markdown]
# # Columns Description:

# %% [markdown]
# ### In dataset, Rape victims are grouped into multiple categories such as
# ###    -Victims_Upto_10_Yrs
# ###    -Victims_Between_10-14_Yrs
# ###    -Victims_Between_14-18_Yrs
# ###    -Victims_Between_18-30_Yrs
# ###    -Victims_Between_30-50_Yrs
# ###    -Victims_Above_50_Yrs

# %%
df['Subgroup'].unique()
# Out:
# array(['Total Rape Victims', 'Victims of Incest Rape',
#        'Victims of Other Rape'], dtype=object)

# %% [markdown]
# ### Rape victims are sub-categorized into two categories:
# ###    -Victims of Incest Rape
# ###    -Victims of Other Rape
#
# ### Total Rape Victims = Victims of Incest Rape + Victims of Other Rape

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Area_Name                  1050 non-null   object
#  1   Year                       1050 non-null   int64
#  2   Subgroup                   1050 non-null   object
#  3   Rape_Cases_Reported        1050 non-null   int64
#  4   Victims_Above_50_Yrs       1050 non-null   int64
#  5   Victims_Between_10-14_Yrs  1050 non-null   int64
#  6   Victims_Between_14-18_Yrs  1050 non-null   int64
#  7   Victims_Between_18-30_Yrs  1050 non-null   int64
#  8   Victims_Between_30-50_Yrs  1050 non-null   int64
#  9   Victims_of_Rape_Total      1050 non-null   int64
#  10  Victims_Upto_10_Yrs        1050 non-null   int64
# dtypes: int64(9), object(2)
# memory usage: 90.4+ KB

# %%
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# ### No missing values in the dataset.

# %%
df['Area_Name'].unique()
# Out:
# array(['Andaman & Nicobar Islands', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra & Nagar Haveli', 'Daman & Diu', 'Delhi', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Lakshadweep', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Odisha', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal'], dtype=object)

# %% [markdown]
# ### Names of 28 Indian states and 7 union territories.

# %%
df['Year'].unique()
# Out:
# array([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010],
#       dtype=int64)

# %% [markdown]
# ### Dataset contains victims of rape data from the year 2001 to 2010.

# %% [markdown]
# # Subgroup Column

# %% [markdown]
# # 1. Total Rape Victims

# %%
tr = df[df['Subgroup'] == 'Total Rape Victims']
tr
# Out:
#                       Area_Name  Year            Subgroup  \
# 0     Andaman & Nicobar Islands  2001  Total Rape Victims
# 3     Andaman & Nicobar Islands  2002  Total Rape Victims
# 6     Andaman & Nicobar Islands  2003  Total Rape Victims
# 9     Andaman & Nicobar Islands  2004  Total Rape Victims
# 12    Andaman & Nicobar Islands  2005  Total Rape Victims
# ...                         ...   ...                 ...
# 1035                West Bengal  2006  Total Rape Victims
# 1038                West Bengal  2007  Total Rape Victims
# 1041                West Bengal  2008  Total Rape Victims
# 1044                West Bengal  2009  Total Rape Victims
# 1047                West Bengal  2010  Total Rape Victims
#
#       Rape_Cases_Reported  Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 0                       3                     0                          0
# 3                       2                     0                          0
# ...

# %%
cols=['Victims_Upto_10_Yrs','Victims_Between_10-14_Yrs','Victims_Between_14-18_Yrs',
     'Victims_Between_18-30_Yrs','Victims_Between_30-50_Yrs','Victims_Above_50_Yrs']

# %%
for i in cols:
    print(f" Total rape victims in India from 2001 to 2010 where {i} was {tr[i].sum()}.")
    print('\n')
# Out:
#  Total rape victims in India from 2001 to 2010 where Victims_Upto_10_Yrs was 5468.
#
#
#  Total rape victims in India from 2001 to 2010 where Victims_Between_10-14_Yrs was 12420.
#
#
#  Total rape victims in India from 2001 to 2010 where Victims_Between_14-18_Yrs was 27870.
#
#
#  Total rape victims in India from 2001 to 2010 where Victims_Between_18-30_Yrs was 111792.
#
#
#  Total rape victims in India from 2001 to 2010 where Victims_Between_30-50_Yrs was 31624.
#
#
#  Total rape victims in India from 2001 to 2010 where Victims_Above_50_Yrs was 980.

# %%
tr['Rape_Cases_Reported'].sum()
# Out:
# 190008

# %% [markdown]
# ### Total rape cases reported in India from 2001 to 2010 was 190008.

# %%
tr['Victims_of_Rape_Total'].sum()
# Out:
# 190154

# %% [markdown]
# ### Total number of rape victims in India from 2001 to 2010 was 190154.

# %% [markdown]
# # Yearly Basis.

# %%
yearly_basis=tr.groupby('Year')['Rape_Cases_Reported','Victims_of_Rape_Total'].sum().reset_index()

# %%
yb=pd.DataFrame(yearly_basis)

# %%
yb
# Out:
#    Year  Rape_Cases_Reported  Victims_of_Rape_Total
# 0  2001                16075                  16078
# 1  2002                16373                  16378
# 2  2003                15847                  15856
# 3  2004                18233                  18239
# 4  2005                18359                  18376
# 5  2006                19348                  19365
# 6  2007                20737                  20771
# 7  2008                21467                  21485
# 8  2009                21397                  21413
# 9  2010                22172                  22193

# %%
# on average per-day rape cases reported in India froom 2001 to 2010.
yb['Rape_Cases_Reported']/365
# Out:
# 0    44.041096
# 1    44.857534
# 2    43.416438
# 3    49.953425
# 4    50.298630
# 5    53.008219
# 6    56.813699
# 7    58.813699
# 8    58.621918
# 9    60.745205
# Name: Rape_Cases_Reported, dtype: float64

# %%
# on average per-day rape cases count in India froom 2001 to 2010.
yb['Victims_of_Rape_Total']/365
# Out:
# 0    44.049315
# 1    44.871233
# 2    43.441096
# 3    49.969863
# 4    50.345205
# 5    53.054795
# 6    56.906849
# 7    58.863014
# 8    58.665753
# 9    60.802740
# Name: Victims_of_Rape_Total, dtype: float64

# %%
plt.figure(figsize=(10,5))
plt.bar(yb['Year'],yb['Rape_Cases_Reported'])
plt.show()

# %% [markdown]
# ### Maximum number of rape cases were reported in the year 2010

# %%
plt.figure(figsize=(10,5))
plt.bar(yb['Year'],yb['Victims_of_Rape_Total'])
plt.show()

# %% [markdown]
# ### Rape cases have been steadily rising in India from 2001 to 2010.

# %%
yearly_basis1=tr.groupby('Year')[cols].sum().reset_index()

# %%
yb1=pd.DataFrame(yearly_basis1)
yb1
# Out:
#    Year  Victims_Upto_10_Yrs  Victims_Between_10-14_Yrs  \
# 0  2001                  530                       1440
# 1  2002                  411                        854
# 2  2003                  389                        931
# 3  2004                  532                       1090
# 4  2005                  557                       1174
# 5  2006                  512                       1081
# 6  2007                  617                       1355
# 7  2008                  639                       1331
# 8  2009                  710                       1760
# 9  2010                  571                       1404
#
#    Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 0                       3911                       7881
# 1                       1325                      10730
# 2                       1792                       9873
# 3                       2004                      11343
# 4                       2344                      10809
# ...

# %%
plt.figure(figsize=(10,5))
plt.bar(yb1['Year'],yb1['Victims_Upto_10_Yrs'])
plt.show()

# %% [markdown]
# ### Maximum number of rape cases where Victims_Upto_10_Yrs was in the year 2009.

# %%
plt.figure(figsize=(10,5))
plt.bar(yb1['Year'],yb1['Victims_Between_10-14_Yrs'])
plt.show()

# %% [markdown]
# ### Maximum number of rape cases where Victims_Between_10-14_Yrs was in the year 2009.

# %%
yb1.plot.bar(stacked=True)

# %% [markdown]
# ### Rape cases have been steadily rising in India from 2001 to 2010.

# %% [markdown]
# # Year Wise

# %% [markdown]
# ## 1. 2001

# %%
y_2001=tr.groupby('Year').get_group(2001)
y_2001
# Out:
#                       Area_Name  Year            Subgroup  \
# 0     Andaman & Nicobar Islands  2001  Total Rape Victims
# 30               Andhra Pradesh  2001  Total Rape Victims
# 60            Arunachal Pradesh  2001  Total Rape Victims
# 90                        Assam  2001  Total Rape Victims
# 120                       Bihar  2001  Total Rape Victims
# 150                  Chandigarh  2001  Total Rape Victims
# 180                Chhattisgarh  2001  Total Rape Victims
# 210        Dadra & Nagar Haveli  2001  Total Rape Victims
# 240                 Daman & Diu  2001  Total Rape Victims
# 270                       Delhi  2001  Total Rape Victims
# 300                         Goa  2001  Total Rape Victims
# 330                     Gujarat  2001  Total Rape Victims
# 360                     Haryana  2001  Total Rape Victims
# 390            Himachal Pradesh  2001  Total Rape Victims
# 420             Jammu & Kashmir  2001  Total Rape Victims
# ...

# %%
y_2001[['Area_Name','Victims_of_Rape_Total']].reset_index()
# Out:
#     index                  Area_Name  Victims_of_Rape_Total
# 0       0  Andaman & Nicobar Islands                      3
# 1      30             Andhra Pradesh                    871
# 2      60          Arunachal Pradesh                     33
# 3      90                      Assam                    817
# 4     120                      Bihar                    888
# 5     150                 Chandigarh                     19
# 6     180               Chhattisgarh                    959
# 7     210       Dadra & Nagar Haveli                      6
# 8     240                Daman & Diu                      0
# 9     270                      Delhi                    383
# 10    300                        Goa                     12
# 11    330                    Gujarat                    286
# 12    360                    Haryana                    398
# 13    390           Himachal Pradesh                    124
# 14    420            Jammu & Kashmir                    169
# ...

# %%
plt.bar(range(0,35),y_2001['Victims_of_Rape_Total'])
plt.show()

# %% [markdown]
# ### In the year 2001 Madhya Pradesh witnessed maximun number of cases.

# %% [markdown]
# # Area Wise

# %%
area_wise=tr.groupby('Area_Name')['Rape_Cases_Reported','Victims_of_Rape_Total'].sum().reset_index()

# %%
aw=pd.DataFrame(area_wise)
aw
# Out:
#                     Area_Name  Rape_Cases_Reported  Victims_of_Rape_Total
# 0   Andaman & Nicobar Islands                   84                     84
# 1              Andhra Pradesh                10696                  10696
# 2           Arunachal Pradesh                  412                    412
# 3                       Assam                12762                  12762
# 4                       Bihar                11263                  11263
# 5                  Chandigarh                  227                    228
# 6                Chhattisgarh                 9751                   9751
# 7        Dadra & Nagar Haveli                   49                     49
# 8                 Daman & Diu                   14                     14
# 9                       Delhi                 5146                   5171
# 10                        Goa                  266                    270
# 11                    Gujarat                 3337                   3339
# ...

# %%
plt.figure(figsize=(10,5))
plt.bar(range(0,35),aw['Rape_Cases_Reported'])
plt.show()

# %% [markdown]
# ### Maximum number of rape cases were reported in Madhya Pradesh and West Bengal from 2001 to 2010.

# %%
plt.figure(figsize=(10,5))
plt.bar(range(0,35),aw['Victims_of_Rape_Total'])
plt.show()

# %% [markdown]
# ### Maximum number of rapes happened in Madhya Pradesh and West Bengal from 2001 to 2010.

# %%
aw[['Area_Name','Victims_of_Rape_Total']].sort_values('Victims_of_Rape_Total')[0:10]
# Out:
#                     Area_Name  Victims_of_Rape_Total
# 18                Lakshadweep                      7
# 8                 Daman & Diu                     14
# 7        Dadra & Nagar Haveli                     49
# 26                 Puducherry                     57
# 0   Andaman & Nicobar Islands                     84
# 29                     Sikkim                    149
# 24                   Nagaland                    176
# 5                  Chandigarh                    228
# 10                        Goa                    270
# 21                    Manipur                    273

# %% [markdown]
# ### Top 10 best states/UT's.

# %%
aw[['Area_Name','Victims_of_Rape_Total']].sort_values('Victims_of_Rape_Total',ascending=False)[0:5]
# Out:
#          Area_Name  Victims_of_Rape_Total
# 19  Madhya Pradesh                  29257
# 34     West Bengal                  16378
# 32   Uttar Pradesh                  15053
# 20     Maharashtra                  14505
# 3            Assam                  12762

# %% [markdown]
# ### Top 5 worst states.

# %% [markdown]
# # State List

# %%
state_list=aw.copy()

# %%
state_list.drop([0,5,7,8,9,18,26],axis=0,inplace=True)

# %%
len(state_list)
# Out:
# 28

# %%
state_list
# Indian States
# Out:
#             Area_Name  Rape_Cases_Reported  Victims_of_Rape_Total
# 1      Andhra Pradesh                10696                  10696
# 2   Arunachal Pradesh                  412                    412
# 3               Assam                12762                  12762
# 4               Bihar                11263                  11263
# 6        Chhattisgarh                 9751                   9751
# 10                Goa                  266                    270
# 11            Gujarat                 3337                   3339
# 12            Haryana                 5009                   5009
# 13   Himachal Pradesh                 1453                   1453
# 14    Jammu & Kashmir                 2230                   2228
# 15          Jharkhand                 7563                   7563
# 16          Karnataka                 3917                   3917
# 17             Kerala                 5296                   5308
# ...

# %%
state_list[['Area_Name','Victims_of_Rape_Total']].sort_values('Victims_of_Rape_Total')[0:5]
# Out:
#             Area_Name  Victims_of_Rape_Total
# 29             Sikkim                    149
# 24           Nagaland                    176
# 10                Goa                    270
# 21            Manipur                    273
# 2   Arunachal Pradesh                    412

# %% [markdown]
# ### Top 5 best states.

# %%
state_list[['Area_Name','Victims_of_Rape_Total']].sort_values('Victims_of_Rape_Total',ascending=False)[0:5]
# Out:
#          Area_Name  Victims_of_Rape_Total
# 19  Madhya Pradesh                  29257
# 34     West Bengal                  16378
# 32   Uttar Pradesh                  15053
# 20     Maharashtra                  14505
# 3            Assam                  12762

# %% [markdown]
# ### Top 5 worst states.

# %% [markdown]
# # UT List

# %%
ut_list=aw.copy()

# %%
ut_list.drop([1,2,3,4,6,10,11,12,13,14,15,16,17,19,20,21,22,23,24,25,27,28,29,30,31,32,33,34],axis=0,inplace=True)

# %%
len(ut_list)
# Out:
# 7

# %%
ut_list
# Indian UT's
# Out:
#                     Area_Name  Rape_Cases_Reported  Victims_of_Rape_Total
# 0   Andaman & Nicobar Islands                   84                     84
# 5                  Chandigarh                  227                    228
# 7        Dadra & Nagar Haveli                   49                     49
# 8                 Daman & Diu                   14                     14
# 9                       Delhi                 5146                   5171
# 18                Lakshadweep                    7                      7
# 26                 Puducherry                   57                     57

# %%
ut_list[['Area_Name','Victims_of_Rape_Total']].sort_values('Victims_of_Rape_Total')
# Out:
#                     Area_Name  Victims_of_Rape_Total
# 18                Lakshadweep                      7
# 8                 Daman & Diu                     14
# 7        Dadra & Nagar Haveli                     49
# 26                 Puducherry                     57
# 0   Andaman & Nicobar Islands                     84
# 5                  Chandigarh                    228
# 9                       Delhi                   5171

# %% [markdown]
# ### Best_UT-- Lakshadweep
# ### Worst_UT-- Delhi

# %%
area_wise1=tr.groupby('Area_Name')[cols].sum().reset_index()

# %%
aw1=pd.DataFrame(area_wise1)
aw1
# Out:
#                     Area_Name  Victims_Upto_10_Yrs  Victims_Between_10-14_Yrs  \
# 0   Andaman & Nicobar Islands                    7                          8
# 1              Andhra Pradesh                  430                       1255
# 2           Arunachal Pradesh                   19                         48
# 3                       Assam                   46                        153
# 4                       Bihar                   31                        102
# 5                  Chandigarh                   31                         46
# 6                Chhattisgarh                  295                       1207
# 7        Dadra & Nagar Haveli                    5                          8
# 8                 Daman & Diu                    5                          1
# 9                       Delhi                  544                        882
# 10                        Goa                   33                         60
# ...

# %%
plt.figure(figsize=(10,5))
plt.bar(range(0,35),aw1['Victims_Upto_10_Yrs'])
plt.show()

# %% [markdown]
# ### Maximum number of rape cases were Victims_Upto_10_Yrs was in Maharashtra from 2001 to 2010.

# %%
plt.figure(figsize=(10,5))
plt.bar(range(0,35),aw1['Victims_Between_10-14_Yrs'])
plt.show()

# %% [markdown]
# ### Maximum number of rape cases were Victims_Between_10-14_Yrs was in Madhya Pradesh from 2001 to 2010.

# %%
aw1.plot.bar(stacked=True)

# %% [markdown]
# ### Maximum number of rapes happened in Madhya Pradesh and West Bengal from 2001 to 2010.

# %% [markdown]
# # State Wise

# %% [markdown]
# ## 1. Karnataka

# %%
kar=tr[tr['Area_Name']=='Karnataka']
kar
# Out:
#      Area_Name  Year            Subgroup  Rape_Cases_Reported  \
# 480  Karnataka  2001  Total Rape Victims                  293
# 483  Karnataka  2002  Total Rape Victims                  292
# 486  Karnataka  2003  Total Rape Victims                  321
# 489  Karnataka  2004  Total Rape Victims                  291
# 492  Karnataka  2005  Total Rape Victims                  343
# 495  Karnataka  2006  Total Rape Victims                  400
# 498  Karnataka  2007  Total Rape Victims                  436
# 501  Karnataka  2008  Total Rape Victims                  446
# 504  Karnataka  2009  Total Rape Victims                  509
# 507  Karnataka  2010  Total Rape Victims                  586
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 480                     0                         63
# 483                     1                         10
# 486                    16                         47
# 489                     0                         15
# ...

# %%
kar[['Year','Rape_Cases_Reported','Victims_of_Rape_Total']]
# Out:
#      Year  Rape_Cases_Reported  Victims_of_Rape_Total
# 480  2001                  293                    293
# 483  2002                  292                    292
# 486  2003                  321                    321
# 489  2004                  291                    291
# 492  2005                  343                    343
# 495  2006                  400                    400
# 498  2007                  436                    436
# 501  2008                  446                    446
# 504  2009                  509                    509
# 507  2010                  586                    586

# %%
plt.bar(kar['Year'],kar['Rape_Cases_Reported'])
plt.show()

# %% [markdown]
# ### Maximum number of rape cases were reported in the year 2010

# %%
plt.bar(kar['Year'],kar['Victims_of_Rape_Total'])
plt.show()

# %% [markdown]
# ### Rape cases have been steadily rising in Karnataka from 2001 to 2010.

# %%
kar[['Year','Victims_Upto_10_Yrs','Victims_Between_10-14_Yrs','Victims_Between_14-18_Yrs',
    'Victims_Between_18-30_Yrs','Victims_Between_30-50_Yrs','Victims_Above_50_Yrs']]
# Out:
#      Year  Victims_Upto_10_Yrs  Victims_Between_10-14_Yrs  \
# 480  2001                   24                         63
# 483  2002                    3                         10
# 486  2003                   18                         47
# 489  2004                   15                         15
# 492  2005                   14                         13
# 495  2006                   23                         16
# 498  2007                   20                         32
# 501  2008                   21                         24
# 504  2009                   39                         49
# 507  2010                   10                         47
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 480                         62                        123
# 483                          6                        218
# 486                         67                        135
# 489                         12                        201
# ...

# %%
plt.bar(kar['Year'],kar['Victims_Upto_10_Yrs'])
plt.show()

# %% [markdown]
# ### Maximum number of rape cases where Victims_Upto_10_Yrs was in the year 2009.

# %%
plt.bar(kar['Year'],kar['Victims_Between_10-14_Yrs'])
plt.show()

# %% [markdown]
# ### Maximum number of rape cases where Victims_Between_10-14_Yrs was in the year 2001.

# %%
kar.plot.bar(stacked=True)

# %% [markdown]
# ### Rape cases have been steadily rising in Karnataka from 2001 to 2010.

# %% [markdown]
# # UT Wise

# %% [markdown]
# ## 1. New Delhi

# %%
ndel=tr[tr['Area_Name']=='Delhi']
ndel
# Out:
#     Area_Name  Year            Subgroup  Rape_Cases_Reported  \
# 270     Delhi  2001  Total Rape Victims                  381
# 273     Delhi  2002  Total Rape Victims                  403
# 276     Delhi  2003  Total Rape Victims                  490
# 279     Delhi  2004  Total Rape Victims                  551
# 282     Delhi  2005  Total Rape Victims                  658
# 285     Delhi  2006  Total Rape Victims                  623
# 288     Delhi  2007  Total Rape Victims                  598
# 291     Delhi  2008  Total Rape Victims                  466
# 294     Delhi  2009  Total Rape Victims                  469
# 297     Delhi  2010  Total Rape Victims                  507
#
#      Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 270                     0                         81
# 273                     0                         54
# 276                     0                         50
# 279                     0                        126
# ...

# %%
ndel[['Year','Rape_Cases_Reported','Victims_of_Rape_Total']]
# Out:
#      Year  Rape_Cases_Reported  Victims_of_Rape_Total
# 270  2001                  381                    383
# 273  2002                  403                    407
# 276  2003                  490                    490
# 279  2004                  551                    551
# 282  2005                  658                    666
# 285  2006                  623                    626
# 288  2007                  598                    602
# 291  2008                  466                    470
# 294  2009                  469                    469
# 297  2010                  507                    507

# %%
# on average per-day rape cases reported
ndel['Rape_Cases_Reported']/365
# Out:
# 270    1.043836
# 273    1.104110
# 276    1.342466
# 279    1.509589
# 282    1.802740
# 285    1.706849
# 288    1.638356
# 291    1.276712
# 294    1.284932
# 297    1.389041
# Name: Rape_Cases_Reported, dtype: float64

# %%
# on average per-day rape cases count
ndel['Victims_of_Rape_Total']/365
# Out:
# 270    1.049315
# 273    1.115068
# 276    1.342466
# 279    1.509589
# 282    1.824658
# 285    1.715068
# 288    1.649315
# 291    1.287671
# 294    1.284932
# 297    1.389041
# Name: Victims_of_Rape_Total, dtype: float64

# %%
plt.bar(ndel['Year'],ndel['Rape_Cases_Reported'])
plt.show()

# %% [markdown]
# ### Maximum number of rape cases were reported in the year 2005.

# %%
plt.bar(ndel['Year'],ndel['Victims_of_Rape_Total'])
plt.show()

# %% [markdown]
# ### Rape cases have been steadily decreasing in Delhi since 2005.

# %%
ndel[['Year','Victims_Upto_10_Yrs','Victims_Between_10-14_Yrs','Victims_Between_14-18_Yrs',
    'Victims_Between_18-30_Yrs','Victims_Between_30-50_Yrs','Victims_Above_50_Yrs']]
# Out:
#      Year  Victims_Upto_10_Yrs  Victims_Between_10-14_Yrs  \
# 270  2001                   48                         81
# 273  2002                   35                         54
# 276  2003                   26                         50
# 279  2004                   60                        126
# 282  2005                   60                        120
# 285  2006                   70                        111
# 288  2007                   76                         94
# 291  2008                   71                         95
# 294  2009                   47                         72
# 297  2010                   51                         79
#
#      Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 270                        154                         59
# 273                         52                        217
# 276                         76                        321
# 279                         77                        282
# ...

# %%
plt.bar(ndel['Year'],ndel['Victims_Upto_10_Yrs'])
plt.show()

# %% [markdown]
# ### Maximum number of rape cases where Victims_Upto_10_Yrs was in the year 2007.

# %%
plt.bar(ndel['Year'],ndel['Victims_Between_10-14_Yrs'])
plt.show()

# %% [markdown]
# ### Maximum number of rape cases where Victims_Between_10-14_Yrs was in the year 2004.

# %%
ndel.plot.bar(stacked=True)

# %% [markdown]
# ### Rape cases have been steadily decreasing in Delhi since 2005.

# %% [markdown]
# # Subgroup Column

# %% [markdown]
# ## 2. Victims of Incest Rape

# %%
ir=df[df['Subgroup']=='Victims of Incest Rape']
ir.head()
# Out:
#                     Area_Name  Year                Subgroup  \
# 1   Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 4   Andaman & Nicobar Islands  2002  Victims of Incest Rape
# 7   Andaman & Nicobar Islands  2003  Victims of Incest Rape
# 10  Andaman & Nicobar Islands  2004  Victims of Incest Rape
# 13  Andaman & Nicobar Islands  2005  Victims of Incest Rape
#
#     Rape_Cases_Reported  Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 1                     1                     0                          0
# 4                     0                     0                          0
# 7                     0                     0                          0
# 10                    0                     0                          0
# 13                    0                     0                          0
#
#     Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 1                           1                          0
# ...

# %%
ir['Rape_Cases_Reported'].sum()
# Out:
# 4216

# %% [markdown]
# ### Total number of reported incest rape cases in India from 2001 to 2010 was 4216.

# %%
ir['Victims_of_Rape_Total'].sum()
# Out:
# 4219

# %% [markdown]
# ### Total number of confirmed incest rape cases in India from 2001 to 2010 was 4219.

# %%
for i in cols:
    print(f" Total incest rape victims in India from 2001 to 2010 where {i} was {ir[i].sum()}.")
    print('\n')
# Out:
#  Total incest rape victims in India from 2001 to 2010 where Victims_Upto_10_Yrs was 239.
#
#
#  Total incest rape victims in India from 2001 to 2010 where Victims_Between_10-14_Yrs was 513.
#
#
#  Total incest rape victims in India from 2001 to 2010 where Victims_Between_14-18_Yrs was 1042.
#
#
#  Total incest rape victims in India from 2001 to 2010 where Victims_Between_18-30_Yrs was 1882.
#
#
#  Total incest rape victims in India from 2001 to 2010 where Victims_Between_30-50_Yrs was 517.
#
#
#  Total incest rape victims in India from 2001 to 2010 where Victims_Above_50_Yrs was 26.

# %% [markdown]
# # Yearly Basis.

# %%
y_ir=ir.groupby('Year')['Rape_Cases_Reported','Victims_of_Rape_Total'].sum().reset_index()
y_ir
# Out:
#    Year  Rape_Cases_Reported  Victims_of_Rape_Total
# 0  2001                  439                    439
# 1  2002                  369                    369
# 2  2003                  399                    400
# 3  2004                  505                    506
# 4  2005                  750                    750
# 5  2006                  431                    431
# 6  2007                  405                    405
# 7  2008                  309                    309
# 8  2009                  321                    322
# 9  2010                  288                    288

# %%
plt.bar(y_ir['Year'],y_ir['Rape_Cases_Reported'])
plt.show()

# %% [markdown]
# ### Maximum number of incest rapes reported in the year 2005.

# %%
plt.bar(y_ir['Year'],y_ir['Victims_of_Rape_Total'])
plt.show()

# %% [markdown]
# ### Maximum number of incest rapes happened in the year 2005.

# %%
y_ir1=ir.groupby('Year')[cols].sum().reset_index()
y_ir1
# Out:
#    Year  Victims_Upto_10_Yrs  Victims_Between_10-14_Yrs  \
# 0  2001                   24                         63
# 1  2002                   15                         58
# 2  2003                   23                         41
# 3  2004                   12                         43
# 4  2005                   36                         64
# 5  2006                   24                         55
# 6  2007                   28                         45
# 7  2008                   23                         54
# 8  2009                   24                         31
# 9  2010                   30                         59
#
#    Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 0                        112                        170
# 1                         77                        176
# 2                         99                        206
# 3                        134                        250
# 4                        164                        357
# ...

# %%
plt.bar(y_ir1['Year'],y_ir1['Victims_Between_14-18_Yrs'])
plt.show()

# %% [markdown]
# ### Maximum number of incest rape cases where Victims_Between_14-18_Yrs was in the year 2005.

# %%
plt.bar(y_ir1['Year'],y_ir1['Victims_Between_18-30_Yrs'])
plt.show()

# %% [markdown]
# ### Maximum number of incest rape cases where Victims_Between_18-30_Yrs was in the year 2005.

# %%
y_ir1.plot.bar(stacked=True)

# %% [markdown]
# ### Incest Rape cases have been steadily decreasing in India since 2005.

# %% [markdown]
# # Area Wise

# %%
a_ir=ir.groupby('Area_Name')['Rape_Cases_Reported','Victims_of_Rape_Total'].sum().reset_index()
a_ir
# Out:
#                     Area_Name  Rape_Cases_Reported  Victims_of_Rape_Total
# 0   Andaman & Nicobar Islands                    1                      1
# 1              Andhra Pradesh                   70                     70
# 2           Arunachal Pradesh                    0                      0
# 3                       Assam                  101                    101
# 4                       Bihar                   43                     43
# 5                  Chandigarh                   17                     17
# 6                Chhattisgarh                  532                    532
# 7        Dadra & Nagar Haveli                    0                      0
# 8                 Daman & Diu                    0                      0
# 9                       Delhi                  231                    231
# 10                        Goa                    7                      7
# 11                    Gujarat                   97                     97
# ...

# %%
plt.bar(range(0,35),a_ir['Rape_Cases_Reported'])
plt.show()

# %% [markdown]
# ### Maximum number of incest rape cases were reported in Madhya Pradesh and Chhattisgarh from 2001 to 2010.

# %%
plt.bar(range(0,35),a_ir['Victims_of_Rape_Total'])
plt.show()

# %% [markdown]
# ### Maximum number of incest rape cases were happened in Madhya Pradesh and Chhattisgarh from 2001 to 2010.

# %%
a_ir[['Area_Name','Victims_of_Rape_Total']].sort_values('Victims_of_Rape_Total')[:5]
# Out:
#                Area_Name  Victims_of_Rape_Total
# 2      Arunachal Pradesh                      0
# 18           Lakshadweep                      0
# 26            Puducherry                      0
# 7   Dadra & Nagar Haveli                      0
# 8            Daman & Diu                      0

# %% [markdown]
# ### Top 5 best states/UT's.

# %%
a_ir[['Area_Name','Victims_of_Rape_Total']].sort_values('Victims_of_Rape_Total',ascending=False)[:5]
# Out:
#          Area_Name  Victims_of_Rape_Total
# 19  Madhya Pradesh                    865
# 6     Chhattisgarh                    532
# 20     Maharashtra                    362
# 28       Rajasthan                    337
# 15       Jharkhand                    321

# %% [markdown]
# ### Top 5 worst states.

# %%
a_ir1=ir.groupby('Area_Name')[cols].sum().reset_index()
a_ir1
# Out:
#                     Area_Name  Victims_Upto_10_Yrs  Victims_Between_10-14_Yrs  \
# 0   Andaman & Nicobar Islands                    0                          0
# 1              Andhra Pradesh                    8                         12
# 2           Arunachal Pradesh                    0                          0
# 3                       Assam                    0                          5
# 4                       Bihar                    1                          5
# 5                  Chandigarh                    3                          3
# 6                Chhattisgarh                   15                         63
# 7        Dadra & Nagar Haveli                    0                          0
# 8                 Daman & Diu                    0                          0
# 9                       Delhi                   36                         62
# 10                        Goa                    1                          0
# ...

# %%
plt.bar(range(0,35),a_ir1['Victims_Between_14-18_Yrs'])
plt.show()

# %% [markdown]
# ### Maximum number of incest rape cases were Victims_Between_14-18_Yrs was in Madhya Pradesh from 2001 to 2010.

# %%
plt.bar(range(0,35),a_ir1['Victims_Between_18-30_Yrs'])
plt.show()

# %% [markdown]
# ### Maximum number of incest rape cases were Victims_Between_18-30_Yrs was in Madhya Pradesh from 2001 to 2010.

# %%
a_ir1.plot.bar(stacked=True)

# %% [markdown]
# ### Maximum number of incest rapes happened in Madhya Pradesh and Chhattisgarh from 2001 to 2010.
